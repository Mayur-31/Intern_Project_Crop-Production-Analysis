# %% [markdown]
# # Exploratory Data Analysis to chart Agriculture highlights using Python

# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# # Data Preparation and Cleaning

# %%
df = pd.read_csv('APY.csv') # Pandas Dataframe Function for load dataset
df
# Out:
#                              State District       Crop  Crop_Year  \
# 0       Andaman and Nicobar Island  NICOBARS  Arecanut       2007
# 1       Andaman and Nicobar Island  NICOBARS  Arecanut       2007
# 2       Andaman and Nicobar Island  NICOBARS  Arecanut       2008
# 3       Andaman and Nicobar Island  NICOBARS  Arecanut       2008
# 4       Andaman and Nicobar Island  NICOBARS  Arecanut       2009
# ...                            ...       ...       ...        ...
# 345331                 West Bengal   PURULIA     Wheat       2015
# 345332                 West Bengal   PURULIA     Wheat       2016
# 345333                 West Bengal   PURULIA     Wheat       2017
# 345334                 West Bengal   PURULIA     Wheat       2018
# 345335                 West Bengal   PURULIA     Wheat       2019
#
#              Season   Area   Production  Yield
# 0       Kharif       2439.6      3415.0   1.40
# 1       Rabi         1626.4      2277.0   1.40
# ...

# %%
df.shape  # Representing Dimensionality of dataset (Rows,Columns)
# Out:
# (345336, 8)

# %%
df.head()  # Return the First 5 rows
# Out:
#                         State District       Crop  Crop_Year       Season  \
# 0  Andaman and Nicobar Island  NICOBARS  Arecanut       2007  Kharif
# 1  Andaman and Nicobar Island  NICOBARS  Arecanut       2007  Rabi
# 2  Andaman and Nicobar Island  NICOBARS  Arecanut       2008  Autumn
# 3  Andaman and Nicobar Island  NICOBARS  Arecanut       2008  Summer
# 4  Andaman and Nicobar Island  NICOBARS  Arecanut       2009  Autumn
#
#     Area   Production  Yield
# 0  2439.6      3415.0   1.40
# 1  1626.4      2277.0   1.40
# 2  4147.0      3060.0   0.74
# 3  4147.0      2660.0   0.64
# 4  4153.0      3120.0   0.75

# %%
df.tail() # Return the Last 5 rows
# Out:
#               State District    Crop  Crop_Year       Season   Area   \
# 345331  West Bengal   PURULIA  Wheat       2015  Rabi          855.0
# 345332  West Bengal   PURULIA  Wheat       2016  Rabi         1366.0
# 345333  West Bengal   PURULIA  Wheat       2017  Rabi         1052.0
# 345334  West Bengal   PURULIA  Wheat       2018  Rabi          833.0
# 345335  West Bengal   PURULIA  Wheat       2019  Rabi          516.0
#
#         Production  Yield
# 345331      1241.0   1.45
# 345332      2415.0   1.77
# 345333      2145.0   2.04
# 345334      2114.0   2.54
# 345335       931.0   1.80

# %%
df.sample(5)  # Returns the Random 5 rows
# Out:
#                  State  District        Crop  Crop_Year       Season    Area   \
# 290364   Uttar Pradesh      GONDA       Gram       2001  Rabi          3925.0
# 151668  Madhya Pradesh      SIDHI     Banana       2006  Whole Year       6.0
# 63524            Bihar  BHAGALPUR      Wheat       2001  Rabi         42781.0
# 7855    Andhra Pradesh   ADILABAD      Maize       2010  Rabi          6725.0
# 35816            Assam    BARPETA  Sugarcane       2018  Whole Year     382.0
#
#         Production  Yield
# 290364      2575.0   0.66
# 151668       112.0  18.67
# 63524      69488.0   1.62
# 7855       22462.0   3.34
# 35816      13394.0  35.06

# %%
df.columns   # Column Description......
# States --> Name of states
# District --> Name of districts
# Crop --> Variety of crops
# Crop_Year --> Year
# Season --> Seasons
# Area --> Area in Hectares
# Production --> Production in tonnes
# Yield --> Yield(Tonnes/Hectare)
# Out:
# Index(['State', 'District ', 'Crop', 'Crop_Year', 'Season', 'Area ',
#        'Production', 'Yield'],
#       dtype='object')

# %%
df.info() # This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345336 entries, 0 to 345335
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   State       345336 non-null  object
#  1   District    345336 non-null  object
#  2   Crop        345327 non-null  object
#  3   Crop_Year   345336 non-null  int64
#  4   Season      345336 non-null  object
#  5   Area        345336 non-null  float64
#  6   Production  340388 non-null  float64
#  7   Yield       345336 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 21.1+ MB

# %%
df.dtypes  # Returns the data types in dataset
# Out:
# State          object
# District       object
# Crop           object
# Crop_Year       int64
# Season         object
# Area          float64
# Production    float64
# Yield         float64
# dtype: object

# %%
df.iloc[:,0:3]  # Integer -Location Based indexing for selection by position (Rows,Columns)
# Out:
#                              State District       Crop
# 0       Andaman and Nicobar Island  NICOBARS  Arecanut
# 1       Andaman and Nicobar Island  NICOBARS  Arecanut
# 2       Andaman and Nicobar Island  NICOBARS  Arecanut
# 3       Andaman and Nicobar Island  NICOBARS  Arecanut
# 4       Andaman and Nicobar Island  NICOBARS  Arecanut
# ...                            ...       ...       ...
# 345331                 West Bengal   PURULIA     Wheat
# 345332                 West Bengal   PURULIA     Wheat
# 345333                 West Bengal   PURULIA     Wheat
# 345334                 West Bengal   PURULIA     Wheat
# 345335                 West Bengal   PURULIA     Wheat
#
# [345336 rows x 3 columns]

# %%
df.loc[:,["Crop","Production"]].head(10)  # Selection By label (Rows,Columns)
# Out:
#        Crop  Production
# 0  Arecanut      3415.0
# 1  Arecanut      2277.0
# 2  Arecanut      3060.0
# 3  Arecanut      2660.0
# 4  Arecanut      3120.0
# 5  Arecanut      2080.0
# 6  Arecanut      2000.0
# 7  Arecanut      2061.0
# 8  Arecanut      2083.0
# 9  Arecanut      1525.0

# %%
df['Season'].value_counts()  #The value_counts() function is used to get a Series containing counts of unique values.
# Out:
# Kharif         138369
# Rabi           100951
# Whole Year      68680
# Summer          22098
# Winter           8249
# Autumn           6989
# Name: Season, dtype: int64

# %%
df['Crop'].value_counts()  #The value_counts() function is used to get a Series containing counts of unique values.
# Out:
# Rice                     21611
# Maize                    20513
# Moong(Green Gram)        15139
# Urad                     14581
# Sesamum                  13049
# Groundnut                12586
# Wheat                    11220
# Rapeseed &Mustard        11034
# Sugarcane                10942
# Arhar/Tur                10885
# Potato                   10756
# Onion                    10675
# Gram                     10474
# Jowar                     9769
# Dry chillies              8971
# Bajra                     8165
# Peas & beans (Pulses)     7266
# Sunflower                 7244
# Small millets             6985
# Cotton(lint)              6475
# Masoor                    6383
# Linseed                   5892
# Barley                    5891
# Ragi                      5757
# Sweet potato              5742
# Other Kharif pulses       5720
# Turmeric                  5607
# Horse-gram                5424
# Garlic                    5279
# Coriander                 5037
# ...

# %%
df['State'].value_counts()  #The value_counts() function is used to get a Series containing counts of unique values.
# Out:
# Uttar Pradesh                 44781
# Madhya Pradesh                29906
# Karnataka                     27493
# Bihar                         24697
# Rajasthan                     20363
# Tamil Nadu                    18507
# Assam                         18186
# Maharashtra                   17922
# Andhra Pradesh                16363
# Odisha                        16153
# Chhattisgarh                  15285
# Gujarat                       14053
# West Bengal                   12596
# Haryana                        8305
# Uttarakhand                    6702
# Nagaland                       5676
# Himachal Pradesh               5043
# Jharkhand                      5004
# Kerala                         4870
# Telangana                      4684
# Arunachal Pradesh              4345
# Meghalaya                      4322
# Jammu and Kashmir              4175
# Punjab                         4142
# Manipur                        3093
# Tripura                        2557
# ...

# %%
df.describe()  #The describe() method returns description of the data in the DataFrame.
# Out:
#            Crop_Year         Area     Production          Yield
# count  345336.000000  3.453360e+05  3.403880e+05  345336.000000
# mean     2008.887512  1.167147e+04  9.584726e+05      79.423135
# std         6.564361  4.584079e+04  2.153068e+07     916.678396
# min      1997.000000  4.000000e-03  0.000000e+00       0.000000
# 25%      2003.000000  7.400000e+01  8.700000e+01       0.550000
# 50%      2009.000000  5.320000e+02  7.170000e+02       1.000000
# 75%      2015.000000  4.112000e+03  7.182000e+03       2.470000
# max      2020.000000  8.580100e+06  1.597800e+09   43958.330000

# %%
df.isnull().sum()  # Checking of Missing Values in Dataset
# Out:
# State            0
# District         0
# Crop             9
# Crop_Year        0
# Season           0
# Area             0
# Production    4948
# Yield            0
# dtype: int64

# %% [markdown]
# # Next step would be dropping these samples as we have sufficiently big dataset. Missing value accounts for only 1.5% of total sample size.

# %%
df.dropna(subset=["Production"],axis=0,inplace=True)  # The dropna() function is used to remove missing values.

# %%
df.dropna(subset=["Crop"],axis=0,inplace=True)    # The dropna() function is used to remove missing values.

# %%
df.isnull().sum()
# Out:
# State         0
# District      0
# Crop          0
# Crop_Year     0
# Season        0
# Area          0
# Production    0
# Yield         0
# dtype: int64

# %%
df.duplicated().sum()  # Returns the Duplicated values in dataset
# Out:
# 0

# %%
df.nunique()   # Returns the unique values in dataset
# Out:
# State            37
# District        707
# Crop             55
# Crop_Year        24
# Season            6
# Area          47655
# Production    60410
# Yield         10595
# dtype: int64

# %% [markdown]
# # Checking for Correlation between variables

# %%
plt.tick_params(labelsize=10)
sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# # There is no variable showing high correlation with any other variable in the dataset.

# %% [markdown]
# # Univarate Analysis

# %%
plt.boxplot(df['Yield'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235bfe39ee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x235bfe494c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x235bfe39d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x235bfe49a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235bfe49d30>],
#  'means': []}

# %%
plt.boxplot(df['Production'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235bfebfe20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x235bfecf400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x235bfebfc40>],
#  'medians': [<matplotlib.lines.Line2D at 0x235bfecf9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235bfecfc70>],
#  'means': []}

# %% [markdown]
# # Looking at distribution of Yield and Production variables. These two variables are highly skewed with lot of outliers.

# %% [markdown]
# # Different proportion of Crop Categories for India

# %%
df1=df["Crop"].value_counts()
df1.plot(radius=3,kind="pie",autopct="%1.1f",pctdistance=0.9)
plt.tick_params(labelsize=10)

# %% [markdown]
# # BiVarate Analysis

# %% [markdown]
# # State-Wise Production status

# %%
plt.figure(figsize= (15,15))
sns.barplot(x=df['Production'],y= df["State"], orient='h')
# Out:
# <AxesSubplot:xlabel='Production', ylabel='State'>

# %% [markdown]
# # Kerala is top state when we look at the quantum of Production for last 19.years.

# %% [markdown]
# # Crop wise Production status

# %%
plt.figure(figsize= (15,15))
sns.barplot(x=df['Production'],y= df["Crop"], orient='h')
# Out:
# <AxesSubplot:xlabel='Production', ylabel='Crop'>

# %% [markdown]
# # Yearwise Production Status

# %%
plt.tick_params(labelsize=10)
df.groupby("Crop_Year")["Production"].agg("sum").plot.bar()
# Out:
# <AxesSubplot:xlabel='Crop_Year'>

# %% [markdown]
# # Season wise Production Status:

# %%
#Season vs Production
season = df.groupby(by='Season')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)
season
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(season.Season, season.Production,errwidth=0)
plt.yscale('log')
plt.title('Seasonal Crops vs Production')
# Out:
# Text(0.5, 1.0, 'Seasonal Crops vs Production')

# %% [markdown]
# # Crop wise Production plot describing production values for all crop types.

# %%
plt.figure(figsize=(15,8))
plt.tick_params(labelsize=10)
df.groupby("Crop")["Production"].agg("count").plot.bar()
plt.show()

# %%
df_2 = pd.crosstab(df['State'], df['Crop'])
df_2
# Out:
# Crop                        Arecanut  Arhar/Tur  Bajra  Banana  Barley  \
# State
# Andaman and Nicobar Island        50         15      0      49       0
# Andhra Pradesh                    59        649    556     308       0
# Arunachal Pradesh                  0         62      0       0       0
# Assam                            568        589      0     543       0
# Bihar                              0        875    246     231     733
# CHANDIGARH                         0          2      0       0       0
# Chhattisgarh                       0        428    460       0     158
# Dadra and Nagar Haveli             0          7      0       0       0
# Daman and Diu                      0          0     21       0       0
# Delhi                              0          4     22       0      22
# Goa                               20          0      0      20       0
# Gujarat                            0        547    962     225       0
# ...

# %%
df_2.plot(kind='bar', stacked=True, figsize = (16,8))
# Out:
# <AxesSubplot:xlabel='State'>

# %% [markdown]
# # Uttar Pradesh is topping in producing more crop categories than any other Indian state.

# %%
df["Crop"].value_counts()[:5]
# Out:
# Rice                 21573
# Maize                20335
# Moong(Green Gram)    14851
# Urad                 14389
# Sesamum              12744
# Name: Crop, dtype: int64

# %%
rice_df = df[df["Crop"]=="Rice"]
print(rice_df.shape)
rice_df[:3]
# Out:
# (21573, 8)
#                           State District   Crop  Crop_Year       Season  \
# 468  Andaman and Nicobar Island  NICOBARS  Rice       2007  Kharif
# 469  Andaman and Nicobar Island  NICOBARS  Rice       2008  Autumn
# 470  Andaman and Nicobar Island  NICOBARS  Rice       2009  Autumn
#
#        Area   Production  Yield
# 468  7333.75     21864.0   2.98
# 469  7900.00     14730.0   1.86
# 470  8140.00     16600.0   2.04

# %%
sns.barplot("Season","Production",data=rice_df)
# Out:
# <AxesSubplot:xlabel='Season', ylabel='Production'>

# %%
plt.figure(figsize=(13,10))
sns.barplot("State","Production",data=rice_df)
plt.xticks(rotation=90)
plt.show()

# %%
'''1.Rice is grown heavily when we look the frequency of crops in India
   2.Rice needs Winter for it mature
   3.State wise Punjab dominates in rice production'''
# Out:
# '1.Rice is grown heavily when we look the frequency of crops in India\n   2.Rice needs Winter for it mature\n   3.State wise Punjab dominates in rice production'

# %%
sns.scatterplot(df['Yield'],df['Production'])
# Out:
# <AxesSubplot:xlabel='Yield', ylabel='Production'>
